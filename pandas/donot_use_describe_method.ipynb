# %% [markdown]
# ## Stop Using The Describe Method in Pandas. Instead, use Skimpy.

# %%
! pip install skimpy
# Out:
# Collecting skimpy
#   Downloading skimpy-0.0.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: jupyter<2.0.0,>=1.0.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from skimpy) (1.0.0)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from skimpy) (8.1.3)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from skimpy) (1.5.2)
# Collecting ipykernel<7.0.0,>=6.7.0
#   Downloading ipykernel-6.21.2-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 617 kB/s eta 0:00:01
# Collecting numpy<2.0.0,>=1.22.2
#   Downloading numpy-1.24.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 8.0 MB/s eta 0:00:01
# Requirement already satisfied: rich<13.0,>=10.9 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from skimpy) (12.6.0)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from skimpy) (2.10.0)
# Collecting typeguard<3.0.0,>=2.12.1
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: jupyter-console in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.4)
# Requirement already satisfied: ipywidgets in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (7.6.5)
# Requirement already satisfied: nbconvert in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.3.0)
# Requirement already satisfied: qtconsole in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (5.4.0)
# Requirement already satisfied: notebook in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jupyter<2.0.0,>=1.0.0->skimpy) (6.4.6)
# Requirement already satisfied: pytz>=2020.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2.8.2)
# Requirement already satisfied: tornado>=6.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.1.0)
# Requirement already satisfied: ipython>=7.23.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (7.30.1)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Downloading jupyter_core-5.2.0-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 998 kB/s eta 0:00:01
# Requirement already satisfied: pyzmq>=20 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (22.3.0)
# Requirement already satisfied: nest-asyncio in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.5.4)
# Collecting comm>=0.1.1
#   Downloading comm-0.1.2-py3-none-any.whl (6.5 kB)
# Collecting debugpy>=1.6.5
#   Downloading debugpy-1.6.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 5.9 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.3)
# Collecting traitlets>=5.4.0
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      |████████████████████████████████| 117 kB 9.2 MB/s eta 0:00:01
# Requirement already satisfied: psutil in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: packaging in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (21.3)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0; python_version < "3.9" in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from rich<13.0,>=10.9->skimpy) (4.3.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from rich<13.0,>=10.9->skimpy) (0.9.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jupyter-console->jupyter<2.0.0,>=1.0.0->skimpy) (3.0.23)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (5.1.3)
# Requirement already satisfied: bleach in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (3.0.3)
# Requirement already satisfied: testpath in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/lib/python3/dist-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (1.5.0)
# Requirement already satisfied: defusedxml in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.9)
# Requirement already satisfied: qtpy>=2.0.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from qtconsole->jupyter<2.0.0,>=1.0.0->skimpy) (2.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.12.1)
# Requirement already satisfied: prometheus-client in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.12.0)
# Requirement already satisfied: argon2-cffi in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.3.0)
# Requirement already satisfied: six>=1.5 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.2->skimpy) (1.16.0)
# Requirement already satisfied: pickleshare in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.5)
# Requirement already satisfied: backcall in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (4.8.0)
# Requirement already satisfied: decorator in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (45.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (2.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from packaging->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.6)
# Requirement already satisfied: wcwidth in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter<2.0.0,>=1.0.0->skimpy) (0.2.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (4.2.1)
# Requirement already satisfied: webencodings in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from bleach->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jinja2>=2.4->nbconvert->jupyter<2.0.0,>=1.0.0->skimpy) (2.0.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from terminado>=0.8.3->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter<2.0.0,>=1.0.0->skimpy) (3.6.0)
# Requirement already satisfied: pycparser in /home/fm-pc-lt-227/.local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->skimpy) (2.21)
# ERROR: streamlit 1.13.0 has requirement protobuf!=3.20.2,<4,>=3.12, but you'll have protobuf 4.21.12 which is incompatible.
# ERROR: numba 0.56.4 has requirement numpy<1.24,>=1.18, but you'll have numpy 1.24.2 which is incompatible.
# ERROR: jupyter-server 2.1.0 has requirement jupyter-client>=7.4.4, but you'll have jupyter-client 7.1.0 which is incompatible.
# ERROR: jupyter-server 2.1.0 has requirement nbconvert>=6.4.4, but you'll have nbconvert 6.3.0 which is incompatible.
# ERROR: jupyter-server 2.1.0 has requirement nbformat>=5.3.0, but you'll have nbformat 5.1.3 which is incompatible.
# ERROR: jupyter-server 2.1.0 has requirement pyzmq>=24, but you'll have pyzmq 22.3.0 which is incompatible.
# ERROR: jupyter-server 2.1.0 has requirement tornado>=6.2.0, but you'll have tornado 6.1 which is incompatible.
# ERROR: ibis-framework 4.0.0 has requirement pytz>=2022.7, but you'll have pytz 2021.3 which is incompatible.
# Installing collected packages: traitlets, jupyter-core, comm, debugpy, ipykernel, numpy, typeguard, skimpy
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.9.1
#     Uninstalling jupyter-core-4.9.1:
#       Successfully uninstalled jupyter-core-4.9.1
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.5.1
#     Uninstalling debugpy-1.5.1:
#       Successfully uninstalled debugpy-1.5.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.6.0
#     Uninstalling ipykernel-6.6.0:
#       Successfully uninstalled ipykernel-6.6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.1
#     Uninstalling numpy-1.22.1:
#       Successfully uninstalled numpy-1.22.1
# Successfully installed comm-0.1.2 debugpy-1.6.6 ipykernel-6.21.2 jupyter-core-5.2.0 numpy-1.24.2 skimpy-0.0.8 traitlets-5.9.0 typeguard-2.13.3

# %%
from skimpy import skim, generate_test_data
import pandas as pd

# %%
df = generate_test_data()
df.head()
# Out:
#      length     width  depth       rnd       class location  booly_col  \
# 0  0.762796  1.468082      9 -0.423534  virtginica       UK      False
# 1  0.031203  0.267769     10  2.102890  virtginica       UK      False
# 2  0.044075  3.571043     12  0.147606      setosa       UK       True
# 3  0.914088  2.838664     15 -0.997567  virtginica      NaN       True
# 4  0.555878  2.214629      5  0.329828      setosa       UK      False
#
#             text       date date_no_freq
# 0  What weather! 2018-01-31          NaT
# 1   How are you? 2018-02-28   1992-01-05
# 2   How are you? 2018-03-31   2022-01-01
# 3           <NA> 2018-04-30          NaT
# 4   How are you? 2018-05-31   2022-01-01

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                                        │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓                                │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃                                │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩                                │
# │ │ Number of rows    │ 1000   │ │ float64     │ 3     │ │ class                 │                                │
# │ │ Number of columns │ 10     │ │ category    │ 2     │ │ location              │                                │
# │ └───────────────────┴────────┘ │ datetime64  │ 2     │ └───────────────────────┘                                │
# │                                │ int64       │ 1     │                                                          │
# │                                │ bool        │ 1     │                                                          │
# │                                │ string      │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name      ┃ NA    ┃ NA %    ┃ mean     ┃ sd     ┃ p0         ┃ p25      ┃ p75    ┃ p100   ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━┩  │
# │ │ length           │     0 │       0 │      0.5 │   0.36 │    1.6e-06 │     0.13 │   0.86 │      1 │ █▃▃▃▄█  │  │
# │ │ width            │     0 │       0 │        2 │    1.9 │     0.0021 │      0.6 │      3 │     14 │   █▃▁   │  │
# │ │ depth            │     0 │       0 │       10 │    3.2 │          2 │        8 │     12 │     20 │ ▁▄█▆▃▁  │  │
# │ │ rnd              │   120 │      12 │    -0.02 │      1 │       -2.8 │    -0.74 │   0.66 │    3.7 │  ▁▄█▅▁  │  │
# │ └──────────────────┴───────┴─────────┴──────────┴────────┴────────────┴──────────┴────────┴────────┴─────────┘  │
# │                                                    category                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                      ┃ NA        ┃ NA %           ┃ ordered               ┃ unique             ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ class                            │         0 │              0 │ False                 │                  2 │  │
# │ │ location                         │         1 │            0.1 │ False                 │                  5 │  │
# │ └──────────────────────────────────┴───────────┴────────────────┴───────────────────────┴────────────────────┘  │
# │                                                    datetime                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name             ┃ NA    ┃ NA %      ┃ first               ┃ last                ┃ frequency        ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩  │
# │ │ date                    │     0 │         0 │     2018-01-31      │     2101-04-30      │ M                │  │
# │ │ date_no_freq            │     3 │       0.3 │     1992-01-05      │     2023-03-04      │ None             │  │
# │ └─────────────────────────┴───────┴───────────┴─────────────────────┴─────────────────────┴──────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ text                      │       6 │        0.6 │                          5.8 │                     5800 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# │                                                      bool                                                       │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                        ┃ true            ┃ true rate                     ┃ hist                ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ booly_col                          │             520 │                          0.52 │       █    █        │  │
# │ └────────────────────────────────────┴─────────────────┴───────────────────────────────┴─────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
